# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Write a python script to display a bar chart for the top data analyst skills using the rankings dataset below
# Data:
# - Power BI=80
# - SQL=60
# - Python=40
# - Excel=40
# - Statistics=20

# %%
ranks=[80,60,40,40,30]
skills=["Python","SQL","Power BI","Excel","Statistics"]
c=["red","blue","yellow","black","green"]
plt.bar(skills,ranks,color=c)
plt.title("Top Data Analyst Skills")
plt.xlabel("Skills",color="blue")
plt.ylabel("Ranks")
plt.show()

# %%
x=["science","commerce","arts"]
y=[200,300,500]
c=["red","blue","green"]
plt.bar(x,y,color=c,linewidth=5,edgecolor="black")
plt.xlabel("courses")
plt.ylabel("students enrolled")
plt.title("students enrolled for different courses 2020")
plt.show()

# %% [markdown]
# ## Line graph

# %%
x=[10,20,30,40,50]
y=[10,35,60,75,90]
z=[25,40,65,80,105]
plt.plot(x,y,color="red")
plt.plot(x,z,color="green")
plt.title("Test Plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["is y","is z"])
plt.show()

# %% [markdown]
# ## Simple Bar Graph

# %%
x=["english","math","kiswahili","biology","chemistry"]
y=[65,95,78,80,75]
c=["black","blue","green","yellow","red"]
plt.bar(x,y,width=0.8,color=c)
plt.xlabel("subjects",color="blue")
plt.ylabel("mean score",color="blue")
plt.title("students mean score in different subjects")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#import pandas as pd

# %% [markdown]
# ## Stacked bar graph

# %%
w=0.5
x=["CSE","ISE","ECE","EEE","Mech"]
boys=[100,40,60,240,300]
girls=[200,70,30,120,15]
plt.bar(x,boys,w,color="green",label="boys")
plt.bar(x,girls,w,bottom=boys,color="red",label="girls")
plt.xlabel("Courses")
plt.ylabel("Students")
plt.title("Students vs Courses")
plt.legend()
plt.show()

# %%
#multiple bar graph
w=0.4
x=["CSE","ISE","ECE","EEE","Mech"]
boys=[100,40,60,240,300]
girls=[200,70,30,120,15]

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]

plt.bar(bar1,boys,w,color="green",label="boys")
plt.bar(bar2,girls,w,color="red",label="girls")
plt.xlabel("Courses")
plt.ylabel("Students")
plt.title("Students vs Courses")
plt.xticks(bar1+w/2,x)
plt.legend()
plt.show()

# %%
#stacked bar graph
w=0.4
x=["USA","Russia","GBR","China","Germany"]
gold=[20,10,6,24,30]
silver=[100,50,30,120,150]
bronze=[200,100,60,240,300]

plt.bar(x,gold,w,label="gold")
plt.bar(x,silver,w,bottom=gold,label="silver")
plt.bar(x,bronze,w,bottom=silver,label="bronze")

plt.xlabel("Countries")
plt.ylabel("Medals")
plt.title("Medals Vs Countries")
plt.legend()
plt.show()

# %%
#multiple bar graphs
w=0.2
x=["USA","Russia","GBR","China","Germany"]
gold=[20,10,6,24,30]
silver=[100,50,30,120,150]
bronze=[200,100,60,240,300]

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]
bar3=[i+w for i in bar2]

plt.bar(bar1,gold,w,label="gold")
plt.bar(bar2,silver,w,label="silver")
plt.bar(bar3,bronze,w,label="bronze")

plt.xlabel("Countries")
plt.ylabel("Medals")
plt.title("Medals Vs Countries")
plt.xticks(bar1+w,x)
plt.legend()
plt.show()

# %%
#Factors leading to students interfaculty transfers by year...number of those tansfered in each faculty
w=0.5
x=[2015,2016,2017,2018]
p_p=[25,20,28,30]
media=[10,18,9,15]
c_marketing=[35,28,40,38]

plt.bar(x,p_p,w,color="yellow",label="p_p")
plt.bar(x,media,w,color="green",bottom=p_p,label="media")
plt.bar(x,c_marketing,w,color="blue",bottom=media,label="c_marketing")

plt.xlabel("years")
plt.ylabel("students transfered")
plt.title("students interfaculty transfer by year")
plt.legend()
plt.show()

# %%
w=0.2
x=[2015,2016,2017,2018]
p_p=[25,20,28,30]
media=[10,18,9,15]
c_marketing=[35,28,40,38]
p_c=[15,20,18,24]

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]
bar3=[i+w for i in bar2]
bar4=[i+w for i in bar3]

plt.bar(bar1,p_p,w,color="red",label="p_p")
plt.bar(bar2,media,w,color="green",label="media")
plt.bar(bar3,c_marketing,w,color="blue",label="c_marketing")
plt.bar(bar4,p_c,w,color="black",label="p_c")

plt.xlabel("years")
plt.ylabel("students transfered")
plt.title("students interfaculty transfer by year")
plt.xticks(bar1+w*1.5,x)
plt.legend()
plt.show()

# %%
w=0.2
x=[2015,2016,2017,2018]
p_p=[25,20,28,30]
media=[10,18,9,15]
c_marketing=[35,28,40,38]

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]
bar3=[i+w for i in bar2]

plt.bar(bar1,p_p,w,color="red",label="p_p")
plt.bar(bar2,media,w,color="green",label="media")
plt.bar(bar3,c_marketing,w,color="blue",label="c_marketing")

plt.xlabel("years")
plt.ylabel("students transfered")
plt.title("students interfaculty transfer by year")
plt.xticks(bar1+w,x)
plt.legend()
plt.show()

# %%
N = 5
 
boys = (20, 35, 30, 35, 27)
girls = (25, 32, 34, 20, 25)
boyStd = (2, 3, 4, 1, 2)
girlStd = (3, 5, 2, 3, 3)
ind = np.arange(N)  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, boys, width, yerr = boyStd)
p2 = plt.bar(ind, girls, width,
             bottom = boys, yerr = girlStd)
 
plt.ylabel('Contribution')
plt.title('Contribution by the teams')
plt.xticks(ind, ('T1', 'T2', 'T3', 'T4', 'T5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('boys', 'girls'))
 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))

# set height of bar
IT = [12, 30, 1, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]

# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
		edgecolor ='grey', label ='IT')
plt.bar(br2, ECE, color ='g', width = barWidth,
		edgecolor ='grey', label ='ECE')
plt.bar(br3, CSE, color ='b', width = barWidth,
		edgecolor ='grey', label ='CSE')

# Adding Xticks
plt.xlabel('Branch', fontweight ='bold', fontsize = 15)
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
		['2015', '2016', '2017', '2018', '2019'])

plt.legend()
plt.show()
